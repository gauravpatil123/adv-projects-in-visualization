# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
df1 = pd.read_csv("../data/global temperatutes/GLB.Ts+dSST.csv")

# %%
df1.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -0.18 -0.24 -0.09 -0.16 -0.10 -0.21 -0.18 -0.10  -.15  -.23  -.22
# 1  1881 -0.19 -0.14  0.03  0.05  0.06 -0.18  0.00 -0.04  -.15  -.22  -.18
# 2  1882  0.16  0.14  0.04 -0.17 -0.15 -0.23 -0.16 -0.07  -.14  -.24  -.17
# 3  1883 -0.29 -0.37 -0.12 -0.18 -0.17 -0.08 -0.06 -0.14  -.21  -.11  -.23
# 4  1884 -0.13 -0.08 -0.36 -0.40 -0.34 -0.36 -0.30 -0.27  -.27  -.25  -.33
#
#     Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0  -.17  -.17   ***   *** -0.12 -0.16  -.20
# 1  -.07  -.09  -.10  -.17  0.05 -0.07  -.19
# 2  -.36  -.11  -.09   .08 -0.09 -0.15  -.18
# 3  -.11  -.17  -.19  -.34 -0.16 -0.09  -.18
# 4  -.31  -.28  -.27  -.11 -0.36 -0.31  -.29

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    144 non-null    int64
#  1   Jan     144 non-null    float64
#  2   Feb     144 non-null    float64
#  3   Mar     144 non-null    float64
#  4   Apr     144 non-null    float64
#  5   May     144 non-null    float64
#  6   Jun     144 non-null    float64
#  7   Jul     144 non-null    float64
#  8   Aug     144 non-null    float64
#  9   Sep     144 non-null    object
#  10  Oct     144 non-null    object
#  11  Nov     144 non-null    object
#  12  Dec     144 non-null    object
#  13  J-D     144 non-null    object
#  14  D-N     144 non-null    object
#  15  DJF     144 non-null    object
#  16  MAM     144 non-null    float64
#  17  JJA     144 non-null    float64
#  18  SON     144 non-null    object
# dtypes: float64(10), int64(1), object(8)
# memory usage: 21.5+ KB

# %%
df1.isna().sum()
# Out:
# Year    0
# Jan     0
# Feb     0
# Mar     0
# Apr     0
# May     0
# Jun     0
# Jul     0
# Aug     0
# Sep     0
# Oct     0
# Nov     0
# Dec     0
# J-D     0
# D-N     0
# DJF     0
# MAM     0
# JJA     0
# SON     0
# dtype: int64

# %%
df1.tail()
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug  Sep   Oct   Nov  \
# 139  2019  0.93  0.95  1.17  1.02  0.85  0.90  0.94  0.95  .93  1.01   .99
# 140  2020  1.17  1.24  1.17  1.13  1.02  0.92  0.90  0.87  .99   .89  1.10
# 141  2021  0.81  0.64  0.89  0.75  0.78  0.84  0.92  0.82  .93  1.00   .94
# 142  2022  0.91  0.89  1.05  0.84  0.84  0.92  0.94  0.95  .90   .97   .73
# 143  2023  0.87  0.97  1.20  1.00  0.93  1.08  1.19  1.24  ***   ***   ***
#
#       Dec   J-D   D-N   DJF   MAM   JJA  SON
# 139  1.09   .98   .96   .93  1.01  0.93  .98
# 140   .81  1.02  1.04  1.17  1.11  0.90  .99
# 141   .86   .85   .84   .76  0.81  0.86  .95
# 142   .79   .89   .90   .89  0.91  0.94  .86
# 143   ***   ***   ***   .88  1.04  1.17  ***

# %%
df1 = df1.replace("***", np.NAN)

# %%
df1.tail()
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug  Sep   Oct   Nov  \
# 139  2019  0.93  0.95  1.17  1.02  0.85  0.90  0.94  0.95  .93  1.01   .99
# 140  2020  1.17  1.24  1.17  1.13  1.02  0.92  0.90  0.87  .99   .89  1.10
# 141  2021  0.81  0.64  0.89  0.75  0.78  0.84  0.92  0.82  .93  1.00   .94
# 142  2022  0.91  0.89  1.05  0.84  0.84  0.92  0.94  0.95  .90   .97   .73
# 143  2023  0.87  0.97  1.20  1.00  0.93  1.08  1.19  1.24  NaN   NaN   NaN
#
#       Dec   J-D   D-N   DJF   MAM   JJA  SON
# 139  1.09   .98   .96   .93  1.01  0.93  .98
# 140   .81  1.02  1.04  1.17  1.11  0.90  .99
# 141   .86   .85   .84   .76  0.81  0.86  .95
# 142   .79   .89   .90   .89  0.91  0.94  .86
# 143   NaN   NaN   NaN   .88  1.04  1.17  NaN

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    144 non-null    int64
#  1   Jan     144 non-null    float64
#  2   Feb     144 non-null    float64
#  3   Mar     144 non-null    float64
#  4   Apr     144 non-null    float64
#  5   May     144 non-null    float64
#  6   Jun     144 non-null    float64
#  7   Jul     144 non-null    float64
#  8   Aug     144 non-null    float64
#  9   Sep     143 non-null    object
#  10  Oct     143 non-null    object
#  11  Nov     143 non-null    object
#  12  Dec     143 non-null    object
#  13  J-D     143 non-null    object
#  14  D-N     142 non-null    object
#  15  DJF     143 non-null    object
#  16  MAM     144 non-null    float64
#  17  JJA     144 non-null    float64
#  18  SON     143 non-null    object
# dtypes: float64(10), int64(1), object(8)
# memory usage: 21.5+ KB

# %%
df1 = df1.apply(pd.to_numeric)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    144 non-null    int64
#  1   Jan     144 non-null    float64
#  2   Feb     144 non-null    float64
#  3   Mar     144 non-null    float64
#  4   Apr     144 non-null    float64
#  5   May     144 non-null    float64
#  6   Jun     144 non-null    float64
#  7   Jul     144 non-null    float64
#  8   Aug     144 non-null    float64
#  9   Sep     143 non-null    float64
#  10  Oct     143 non-null    float64
#  11  Nov     143 non-null    float64
#  12  Dec     143 non-null    float64
#  13  J-D     143 non-null    float64
#  14  D-N     142 non-null    float64
#  15  DJF     143 non-null    float64
#  16  MAM     144 non-null    float64
#  17  JJA     144 non-null    float64
#  18  SON     143 non-null    float64
# dtypes: float64(18), int64(1)
# memory usage: 21.5 KB

# %%
df1_heat = df1.drop(["Year", "J-D", "D-N", "DJF", "MAM", "JJA", "SON"], axis=1)

# %%
df1_heat.head()
# Out:
#     Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# 0 -0.18 -0.24 -0.09 -0.16 -0.10 -0.21 -0.18 -0.10 -0.15 -0.23 -0.22 -0.17
# 1 -0.19 -0.14  0.03  0.05  0.06 -0.18  0.00 -0.04 -0.15 -0.22 -0.18 -0.07
# 2  0.16  0.14  0.04 -0.17 -0.15 -0.23 -0.16 -0.07 -0.14 -0.24 -0.17 -0.36
# 3 -0.29 -0.37 -0.12 -0.18 -0.17 -0.08 -0.06 -0.14 -0.21 -0.11 -0.23 -0.11
# 4 -0.13 -0.08 -0.36 -0.40 -0.34 -0.36 -0.30 -0.27 -0.27 -0.25 -0.33 -0.31

# %%
figure = plt.figure(figsize=(40,6))
figure = sns.heatmap(df1_heat.T, cmap="coolwarm")
figure.set(xticklabels=df1["Year"])
# Out:
# [[Text(0.5, 0, '1880'),
#   Text(1.5, 0, '1881'),
#   Text(2.5, 0, '1882'),
#   Text(3.5, 0, '1883'),
#   Text(4.5, 0, '1884'),
#   Text(5.5, 0, '1885'),
#   Text(6.5, 0, '1886'),
#   Text(7.5, 0, '1887'),
#   Text(8.5, 0, '1888'),
#   Text(9.5, 0, '1889'),
#   Text(10.5, 0, '1890'),
#   Text(11.5, 0, '1891'),
#   Text(12.5, 0, '1892'),
#   Text(13.5, 0, '1893'),
#   Text(14.5, 0, '1894'),
#   Text(15.5, 0, '1895'),
#   Text(16.5, 0, '1896'),
#   Text(17.5, 0, '1897'),
#   Text(18.5, 0, '1898'),
#   Text(19.5, 0, '1899'),
#   Text(20.5, 0, '1900'),
#   Text(21.5, 0, '1901'),
#   Text(22.5, 0, '1902'),
#   Text(23.5, 0, '1903'),
#   Text(24.5, 0, '1904'),
#   Text(25.5, 0, '1905'),
#   Text(26.5, 0, '1906'),
#   Text(27.5, 0, '1907'),
#   Text(28.5, 0, '1908'),
#   Text(29.5, 0, '1909'),
#   Text(30.5, 0, '1910'),
#   Text(31.5, 0, '1911'),
#   Text(32.5, 0, '1912'),
#   Text(33.5, 0, '1913'),
#   Text(34.5, 0, '1914'),
#   Text(35.5, 0, '1915'),
#   Text(36.5, 0, '1916'),
# ...

# %%
figure2 = plt.figure(figsize=(60, 10))
sns.lineplot(df1, x='Year', y="Jan")
sns.lineplot(df1, x="Year", y="Feb")
sns.lineplot(df1, x="Year", y="May")
sns.lineplot(df1, x="Year", y="Dec")
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df_sea = pd.read_csv("../data/global temperatutes/sea-surface-temp_fig-1.csv")

# %%
df_sea.head()
# Out:
#    Year  Annual anomaly  Lower 95% confidence interval  \
# 0  1880          -0.420                      -0.628152
# 1  1881          -0.330                      -0.531096
# 2  1882          -0.348                      -0.545568
# 3  1883          -0.456                      -0.650040
# 4  1884          -0.582                      -0.790152
#
#    Upper 95% confidence interval
# 0                      -0.211848
# 1                      -0.128904
# 2                      -0.150432
# 3                      -0.261960
# 4                      -0.373848

# %%
df_sea.describe()
# Out:
#               Year  Annual anomaly  Lower 95% confidence interval  \
# count   141.000000      141.000000                     141.000000
# mean   1950.000000       -0.300383                      -0.418033
# std      40.847277        0.487778                       0.528319
# min    1880.000000       -1.176000                      -1.320648
# 25%    1915.000000       -0.690000                      -0.842064
# 50%    1950.000000       -0.402000                      -0.531096
# 75%    1985.000000        0.048000                      -0.022200
# max    2020.000000        0.930000                       0.891192
#
#        Upper 95% confidence interval
# count                     141.000000
# mean                       -0.182733
# std                         0.450499
# min                        -1.031352
# 25%                        -0.515328
# 50%                        -0.261960
# 75%                         0.126336
# max                         0.968808

# %%
df_sea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           141 non-null    int64
#  1   Annual anomaly                 141 non-null    float64
#  2   Lower 95% confidence interval  141 non-null    float64
#  3   Upper 95% confidence interval  141 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 4.5 KB

# %%
df_sea.isna().sum()
# Out:
# Year                             0
# Annual anomaly                   0
# Lower 95% confidence interval    0
# Upper 95% confidence interval    0
# dtype: int64

# %%
df_sea_heat = df_sea[df_sea.columns.difference(["Lower 95% confidence interval", "Upper 95% confidence interval", "Year"])]

# %%
df_sea_heat.head()
# Out:
#    Annual anomaly
# 0          -0.420
# 1          -0.330
# 2          -0.348
# 3          -0.456
# 4          -0.582

# %%
figure3 = plt.figure(figsize=(40,3))
figure3 = sns.heatmap(df_sea_heat.T, cmap="coolwarm")
figure3.set(xticklabels=df_sea["Year"])
# Out:
# [[Text(0.5, 0, '1880'),
#   Text(1.5, 0, '1881'),
#   Text(2.5, 0, '1882'),
#   Text(3.5, 0, '1883'),
#   Text(4.5, 0, '1884'),
#   Text(5.5, 0, '1885'),
#   Text(6.5, 0, '1886'),
#   Text(7.5, 0, '1887'),
#   Text(8.5, 0, '1888'),
#   Text(9.5, 0, '1889'),
#   Text(10.5, 0, '1890'),
#   Text(11.5, 0, '1891'),
#   Text(12.5, 0, '1892'),
#   Text(13.5, 0, '1893'),
#   Text(14.5, 0, '1894'),
#   Text(15.5, 0, '1895'),
#   Text(16.5, 0, '1896'),
#   Text(17.5, 0, '1897'),
#   Text(18.5, 0, '1898'),
#   Text(19.5, 0, '1899'),
#   Text(20.5, 0, '1900'),
#   Text(21.5, 0, '1901'),
#   Text(22.5, 0, '1902'),
#   Text(23.5, 0, '1903'),
#   Text(24.5, 0, '1904'),
#   Text(25.5, 0, '1905'),
#   Text(26.5, 0, '1906'),
#   Text(27.5, 0, '1907'),
#   Text(28.5, 0, '1908'),
#   Text(29.5, 0, '1909'),
#   Text(30.5, 0, '1910'),
#   Text(31.5, 0, '1911'),
#   Text(32.5, 0, '1912'),
#   Text(33.5, 0, '1913'),
#   Text(34.5, 0, '1914'),
#   Text(35.5, 0, '1915'),
#   Text(36.5, 0, '1916'),
# ...

# %%
figure4 = plt.figure(figsize=(60, 10))
sns.lineplot(df_sea, x="Year", y="Annual anomaly")
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df_ghg = pd.read_csv("../data/greenhouse gases/historical_emissions/historical_emissions.csv")

# %%
df_ghg.head()
# Out:
#      ISO              Country    Data source                Sector      Gas  \
# 0  WORLD                World  Climate Watch  Total including LUCF  All GHG
# 1    CHN                China  Climate Watch  Total including LUCF  All GHG
# 2    USA        United States  Climate Watch  Total including LUCF  All GHG
# 3    IND                India  Climate Watch  Total including LUCF  All GHG
# 4    EUU  European Union (27)  Climate Watch  Total including LUCF  All GHG
#
#      Unit      2020      2019      2018      2017  ...      1999      1998  \
# 0  MtCO₂e  47513.15  49880.60  49585.91  48390.92  ...  35264.63  35261.24
# 1  MtCO₂e  12295.62  12085.05  11877.10  11366.60  ...   4029.26   4096.86
# 2  MtCO₂e   5289.13   5819.48   5935.52   5728.79  ...   6242.51   6241.11
# 3  MtCO₂e   3166.95   3380.31   3406.53   3241.44  ...   1461.25   1383.29
# 4  MtCO₂e   2957.36   3236.19   3384.48   3466.09  ...   3953.14   4028.24
#
# ...

# %%
df_ghg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 37 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ISO          195 non-null    object
#  1   Country      195 non-null    object
#  2   Data source  195 non-null    object
#  3   Sector       195 non-null    object
#  4   Gas          195 non-null    object
#  5   Unit         195 non-null    object
#  6   2020         195 non-null    float64
#  7   2019         195 non-null    float64
#  8   2018         195 non-null    float64
#  9   2017         195 non-null    float64
#  10  2016         195 non-null    float64
#  11  2015         195 non-null    float64
#  12  2014         195 non-null    float64
#  13  2013         195 non-null    float64
#  14  2012         195 non-null    float64
#  15  2011         195 non-null    float64
#  16  2010         195 non-null    float64
#  17  2009         195 non-null    float64
# ...

# %%
df_ghg.describe()
# Out:
#                2020          2019          2018          2017          2016  \
# count    195.000000    195.000000    195.000000    195.000000    195.000000
# mean     495.680974    519.304051    516.944974    505.226154    498.252000
# std     3534.342900   3699.924223   3677.392044   3584.845889   3532.781075
# min       -0.810000     -0.380000     -0.490000     -0.580000     -0.770000
# 25%        9.540000     10.030000     10.025000      9.695000      9.430000
# 50%       43.190000     41.160000     39.740000     39.520000     39.030000
# 75%      129.915000    133.725000    127.275000    128.720000    129.795000
# max    47513.150000  49880.600000  49585.910000  48390.920000  47691.830000
#
#                2015          2014          2013          2012          2011  \
# count    195.000000    195.000000    195.000000    195.000000    195.000000
# mean     490.212000    490.664000    484.799641    478.637385    473.225897
# ...

# %%
df_ghg.isna().sum()
# Out:
# ISO            0
# Country        0
# Data source    0
# Sector         0
# Gas            0
# Unit           0
# 2020           0
# 2019           0
# 2018           0
# 2017           0
# 2016           0
# 2015           0
# 2014           0
# 2013           0
# 2012           0
# 2011           0
# 2010           0
# 2009           0
# 2008           0
# 2007           0
# 2006           0
# 2005           0
# 2004           0
# 2003           0
# 2002           0
# 2001           0
# 2000           0
# 1999           0
# 1998           0
# 1997           0
# 1996           0
# 1995           0
# 1994           0
# 1993           0
# 1992           0
# 1991           0
# 1990           1
# dtype: int64

# %%
df_ghg_countries = df_ghg.drop(index=0)

# %%
df_ghg_countries.head()
# Out:
#    ISO              Country    Data source                Sector      Gas  \
# 1  CHN                China  Climate Watch  Total including LUCF  All GHG
# 2  USA        United States  Climate Watch  Total including LUCF  All GHG
# 3  IND                India  Climate Watch  Total including LUCF  All GHG
# 4  EUU  European Union (27)  Climate Watch  Total including LUCF  All GHG
# 5  RUS               Russia  Climate Watch  Total including LUCF  All GHG
#
#      Unit      2020      2019      2018      2017  ...     1999     1998  \
# 1  MtCO₂e  12295.62  12085.05  11877.10  11366.60  ...  4029.26  4096.86
# 2  MtCO₂e   5289.13   5819.48   5935.52   5728.79  ...  6242.51  6241.11
# 3  MtCO₂e   3166.95   3380.31   3406.53   3241.44  ...  1461.25  1383.29
# 4  MtCO₂e   2957.36   3236.19   3384.48   3466.09  ...  3953.14  4028.24
# 5  MtCO₂e   1799.98   1889.93   1843.24   1750.27  ...  1742.90  1712.17
#
#       1997     1996     1995     1994     1993     1992     1991     1990
# ...

# %%
df_ghg_countries.head(20)
# Out:
#     ISO                           Country    Data source  \
# 1   CHN                             China  Climate Watch
# 2   USA                     United States  Climate Watch
# 3   IND                             India  Climate Watch
# 4   EUU               European Union (27)  Climate Watch
# 5   RUS                            Russia  Climate Watch
# 6   IDN                         Indonesia  Climate Watch
# 7   BRA                            Brazil  Climate Watch
# 8   JPN                             Japan  Climate Watch
# 9   IRN                              Iran  Climate Watch
# 10  CAN                            Canada  Climate Watch
# 11  SAU                      Saudi Arabia  Climate Watch
# 12  COD  Democratic Republic of the Congo  Climate Watch
# 13  DEU                           Germany  Climate Watch
# 14  KOR                       South Korea  Climate Watch
# 15  MEX                            Mexico  Climate Watch
# ...

# %%
order = df_ghg_countries.sort_values(by=['1990'], ascending=False).iloc[:5]["Country"]

# %%
order
# Out:
# 2          United States
# 4    European Union (27)
# 1                  China
# 5                 Russia
# 7                 Brazil
# Name: Country, dtype: object

# %%
figure5 = plt.figure(figsize=(10, 10))
sns.catplot(df_ghg_countries, x="Country", y="1990", kind="bar", order=order)
plt.ylabel("Top 5 countries for emmisions in 1990")
plt.xticks(rotation=90)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
def ghg_plot(dataframe:pd.DataFrame, year_range:list, figsize:tuple=(80, 80)) -> None:
    n_rows = int(len(year_range)/5)
    fig, axes = plt.subplots(n_rows, 5, sharex=False, figsize=figsize)
    fig.suptitle('CO2 Emmisions of top 5 countries by years 1990-2019')

    for year, ax in zip(year_range, axes.flat):
        # col = index % 5
        # row = math.floor(index / 5)
        year = str(year)
        order = dataframe.sort_values(by=[year], ascending=False).iloc[:5]["ISO"]
        sns.barplot(data=dataframe, x="ISO", y=year, order=order, ax=ax, palette="mako")
        ax.set_title(f"Top 5 countries for emmisions in {year}", fontsize=30)
        ax.tick_params(labelrotation=90, labelsize=24)
        ax.set_xlabel("Countries", fontsize=30)
        ax.set_ylabel("CO2 e", fontsize=30)
    plt.subplots_adjust(hspace = 0.3)

# %%
years = list(range(1990, 2020))

# %%
ghg_plot(df_ghg_countries, years)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
df_ghg_Country_1990 = df_ghg_countries[["Country", "1991"]]

# %%
df_ghg_Country_1990.head()
# Out:
#                Country     1991
# 1                China  3039.78
# 2        United States  5403.58
# 3                India  1074.57
# 4  European Union (27)  4203.43
# 5               Russia  2563.84

# %%
df_ghg_Country_1990.to_csv("../data/greenhouse gases/test1991.csv")

# %%
df_ghg_countries.to_csv("../data/greenhouse gases/ghg_countries.csv")

# %%
df_ghg_countries
# Out:
#      ISO              Country    Data source                Sector      Gas  \
# 1    CHN                China  Climate Watch  Total including LUCF  All GHG
# 2    USA        United States  Climate Watch  Total including LUCF  All GHG
# 3    IND                India  Climate Watch  Total including LUCF  All GHG
# 4    EUU  European Union (27)  Climate Watch  Total including LUCF  All GHG
# 5    RUS               Russia  Climate Watch  Total including LUCF  All GHG
# ..   ...                  ...            ...                   ...      ...
# 190  COK         Cook Islands  Climate Watch  Total including LUCF  All GHG
# 191  NRU                Nauru  Climate Watch  Total including LUCF  All GHG
# 192  TUV               Tuvalu  Climate Watch  Total including LUCF  All GHG
# 193  NIU                 Niue  Climate Watch  Total including LUCF  All GHG
# 194  FJI                 Fiji  Climate Watch  Total including LUCF  All GHG
#
# ...

# %%
df_ghg_countries_melt  = df_ghg_countries.melt(id_vars=["ISO", "Country", "Data source", "Sector", "Gas", "Unit"], var_name="Year", value_name="Total GHG")

# %%
df_ghg_countries_melt_sorted = df_ghg_countries_melt.sort_values(["Country", "Year"])

# %% [markdown]
# Normalizing GHG Countries Dataset

# %%
df_ghg_countries_melt_sorted['Country'] = df_ghg_countries_melt_sorted['Country'].replace(['European Union (27)'], 'EU (27)')
df_ghg_countries_melt_sorted['Country'] = df_ghg_countries_melt_sorted['Country'].replace(['United Kingdom'], 'UK')
df_ghg_countries_melt_sorted['Country'] = df_ghg_countries_melt_sorted['Country'].replace(['United States'], 'USA')

# %%
df_ghg_countries_melt_sorted.to_csv("../data/greenhouse gases/normalized_historical_ghg.csv")

# %% [markdown]
# Filtering Annual Global Temparatures Anomaly

# %%
df_annual_anomaly_temp = pd.read_csv("../data/global temperatutes/HadCRUT.5.0.1.0.analysis.summary_series.global.annual.csv")

# %%
df_annual_anomaly_temp.head()
# Out:
#    Time  Anomaly (deg C)  Lower confidence limit (2.5%)  \
# 0  1850        -0.417659                      -0.589203
# 1  1851        -0.233350                      -0.411868
# 2  1852        -0.229399                      -0.409382
# 3  1853        -0.270354                      -0.430009
# 4  1854        -0.291630                      -0.432824
#
#    Upper confidence limit (97.5%)
# 0                       -0.246115
# 1                       -0.054832
# 2                       -0.049416
# 3                       -0.110700
# 4                       -0.150436

# %%
df_annual_anomaly_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 4 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Time                            174 non-null    int64
#  1   Anomaly (deg C)                 174 non-null    float64
#  2   Lower confidence limit (2.5%)   174 non-null    float64
#  3   Upper confidence limit (97.5%)  174 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 5.6 KB

# %%
df_annual_anomaly_temp_filtered = df_annual_anomaly_temp[(df_annual_anomaly_temp["Time"] > 1900)]

# %%
df_annual_anomaly_temp_filtered
# Out:
#      Time  Anomaly (deg C)  Lower confidence limit (2.5%)  \
# 51   1901        -0.293429                      -0.429674
# 52   1902        -0.438984                      -0.575428
# 53   1903        -0.533326                      -0.660819
# 54   1904        -0.597561                      -0.728832
# 55   1905        -0.407751                      -0.535029
# ..    ...              ...                            ...
# 169  2019         0.891073                       0.856787
# 170  2020         0.922794                       0.888212
# 171  2021         0.761856                       0.725443
# 172  2022         0.801284                       0.765251
# 173  2023         0.968013                       0.887953
#
#      Upper confidence limit (97.5%)
# 51                        -0.157183
# 52                        -0.302540
# 53                        -0.405833
# 54                        -0.466290
# 55                        -0.280474
# ..                              ...
# ...

# %%
df_annual_anomaly_temp_filtered.to_csv("../data/global temperatutes/annual_temp_anomaly_filtered.csv")

# %% [markdown]
# Esri Map Polygon data

# %%
df_esri_world_map = pd.read_csv("../data/maps/World_Countries_Generalized.csv")

# %%
df_esri_world_map.head()
# Out:
#    FID         COUNTRY ISO     COUNTRYAFF AFF_ISO  SHAPE_Length  SHAPE_Area
# 0    1     Afghanistan  AF    Afghanistan      AF     50.803210   62.566714
# 1    2         Albania  AL        Albania      AL      9.625038    3.073540
# 2    3         Algeria  DZ        Algeria      DZ     70.540082  213.513461
# 3    4  American Samoa  AS  United States      US      0.600124    0.013720
# 4    5         Andorra  AD        Andorra      AD      0.937352    0.055585

# %%
import country_converter as coco

# %%
df_esri_world_map = df_esri_world_map.rename(columns={"ISO":"ISO2"})

# %%
df_esri_world_map["ISO"] = df_esri_world_map["ISO2"]

# %%
df_esri_world_map.head(2)
# Out:
#    FID      COUNTRY ISO2   COUNTRYAFF AFF_ISO  SHAPE_Length  SHAPE_Area ISO
# 0    1  Afghanistan   AF  Afghanistan      AF     50.803210   62.566714  AF
# 1    2      Albania   AL      Albania      AL      9.625038    3.073540  AL

# %%
cc = coco.CountryConverter()

# %%
df_esri_world_map["ISO"] = cc.pandas_convert(df_esri_world_map["ISO"], to="ISO3")
# Out:
# nan not found in ISO3

# %%
df_esri_world_map.head(3)
# Out:
#    FID      COUNTRY ISO2   COUNTRYAFF AFF_ISO  SHAPE_Length  SHAPE_Area  ISO
# 0    1  Afghanistan   AF  Afghanistan      AF     50.803210   62.566714  AFG
# 1    2      Albania   AL      Albania      AL      9.625038    3.073540  ALB
# 2    3      Algeria   DZ      Algeria      DZ     70.540082  213.513461  DZA

# %% [markdown]
# Map Polygon data + normalised ghg data

# %%
df_ghg_countries_melt_sorted.head()
# Out:
#       ISO      Country    Data source                Sector      Gas    Unit  \
# 5932  AFG  Afghanistan  Climate Watch  Total including LUCF  All GHG  MtCO₂e
# 5738  AFG  Afghanistan  Climate Watch  Total including LUCF  All GHG  MtCO₂e
# 5544  AFG  Afghanistan  Climate Watch  Total including LUCF  All GHG  MtCO₂e
# 5350  AFG  Afghanistan  Climate Watch  Total including LUCF  All GHG  MtCO₂e
# 5156  AFG  Afghanistan  Climate Watch  Total including LUCF  All GHG  MtCO₂e
#
#       Year  Total GHG
# 5932  1990       9.24
# 5738  1991       9.51
# 5544  1992       9.16
# 5350  1993       9.29
# 5156  1994       9.34

# %% [markdown]
# ghg countries sorted with both ISO's (2 & 3)

# %%
df_ghg_countries_ISO = df_ghg_countries_melt_sorted

# %%
df_ghg_countries_ISO["ISO2"] = cc.pandas_convert(df_ghg_countries_ISO["ISO"], to="ISO2")
# Out:
# EUU not found in ISO3

# %%
df_ghg_countries_ISO.head()
# Out:
#       ISO      Country    Data source                Sector      Gas    Unit  \
# 5932  AFG  Afghanistan  Climate Watch  Total including LUCF  All GHG  MtCO₂e
# 5738  AFG  Afghanistan  Climate Watch  Total including LUCF  All GHG  MtCO₂e
# 5544  AFG  Afghanistan  Climate Watch  Total including LUCF  All GHG  MtCO₂e
# 5350  AFG  Afghanistan  Climate Watch  Total including LUCF  All GHG  MtCO₂e
# 5156  AFG  Afghanistan  Climate Watch  Total including LUCF  All GHG  MtCO₂e
#
#       Year  Total GHG ISO2
# 5932  1990       9.24   AF
# 5738  1991       9.51   AF
# 5544  1992       9.16   AF
# 5350  1993       9.29   AF
# 5156  1994       9.34   AF

# %%
df_ghg_countries_ISO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6014 entries, 5932 to 53
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ISO          6014 non-null   object
#  1   Country      6014 non-null   object
#  2   Data source  6014 non-null   object
#  3   Sector       6014 non-null   object
#  4   Gas          6014 non-null   object
#  5   Unit         6014 non-null   object
#  6   Year         6014 non-null   object
#  7   Total GHG    6013 non-null   float64
#  8   ISO2         6014 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 469.8+ KB

# %%
df_ghg_countries_ISO.to_csv("../data/greenhouse gases/ISO_normalised_ghg_countries.csv")

# %%
df_map_ghg_right = pd.merge(df_esri_world_map, df_ghg_countries_melt_sorted, how="right", on="ISO")

# %%
df_map_ghg_right.head(10)
# Out:
#    FID      COUNTRY ISO2_x   COUNTRYAFF AFF_ISO  SHAPE_Length  SHAPE_Area  \
# 0  1.0  Afghanistan     AF  Afghanistan      AF      50.80321   62.566714
# 1  1.0  Afghanistan     AF  Afghanistan      AF      50.80321   62.566714
# 2  1.0  Afghanistan     AF  Afghanistan      AF      50.80321   62.566714
# 3  1.0  Afghanistan     AF  Afghanistan      AF      50.80321   62.566714
# 4  1.0  Afghanistan     AF  Afghanistan      AF      50.80321   62.566714
# 5  1.0  Afghanistan     AF  Afghanistan      AF      50.80321   62.566714
# 6  1.0  Afghanistan     AF  Afghanistan      AF      50.80321   62.566714
# 7  1.0  Afghanistan     AF  Afghanistan      AF      50.80321   62.566714
# 8  1.0  Afghanistan     AF  Afghanistan      AF      50.80321   62.566714
# 9  1.0  Afghanistan     AF  Afghanistan      AF      50.80321   62.566714
#
#    ISO      Country    Data source                Sector      Gas    Unit  \
# 0  AFG  Afghanistan  Climate Watch  Total including LUCF  All GHG  MtCO₂e
# ...

# %%
df_map_ghg_right.to_csv("../data/greenhouse gases/map_normalised_historical_ghg.csv")

# %% [markdown]
# # Ice Sheets

# %%
df_ice_sheets_all = pd.read_csv("../data/ice sheets/imbie_all_2021_Gt.csv")
df_ice_sheets_all_mm = pd.read_csv("../data/ice sheets/imbie_all_2021_mm.csv")

# %%
df_ice_sheets_all.head(10)
# Out:
#         Year  Mass balance (Gt/yr)  Mass balance uncertainty (Gt/yr)  \
# 0  1992.0000               22.5333                          127.4965
# 1  1992.0833               22.5333                          127.4965
# 2  1992.1667               22.5333                          127.4965
# 3  1992.2500             -138.4220                          118.0717
# 4  1992.3333             -138.4220                          118.0717
# 5  1992.4167              -63.2290                          102.8949
# 6  1992.5000              -63.2290                          102.8949
# 7  1992.5833              -63.2290                          102.8949
# 8  1992.6667              -63.2290                          102.8949
# 9  1992.7500              -63.2290                          102.8949
#
#    Cumulative mass balance (Gt)  Cumulative mass balance uncertainty (Gt)
# 0                        1.8778                                   36.8051
# ...

# %%
df_years_ice_sheets_all = df_ice_sheets_all.drop(df_ice_sheets_all[df_ice_sheets_all["Year"] % 1 > 0000].index)

# %%
df_years_ice_sheets_all["Year"] = df_years_ice_sheets_all["Year"].astype(int)

# %%
df_years_ice_sheets_all.head(5)
# Out:
#     Year  Mass balance (Gt/yr)  Mass balance uncertainty (Gt/yr)  \
# 0   1992               22.5333                          127.4965
# 12  1993             -104.5494                          103.9689
# 24  1994             -195.5413                          102.8685
# 36  1995             -142.9034                          116.2499
# 48  1996              -59.9941                          117.2250
#
#     Cumulative mass balance (Gt)  Cumulative mass balance uncertainty (Gt)
# 0                         1.8778                                   36.8051
# 12                      -63.0330                                  116.0348
# 24                     -175.1651                                  155.7391
# 36                     -366.3200                                  187.2990
# 48                     -486.7987                                  220.4490

# %%
df_ice_sheets_all_mm.head(5)
# Out:
#         Year  Mass balance (mm/yr)  Mass balance uncertainty (mm/yr)  \
# 0  1992.0000                 -0.06                             -0.35
# 1  1992.0833                 -0.06                             -0.35
# 2  1992.1667                 -0.06                             -0.35
# 3  1992.2500                  0.38                             -0.33
# 4  1992.3333                  0.38                             -0.33
#
#    Cumulative mass balance (mm)  Cumulative mass balance uncertainty (mm)
# 0                         -0.01                                     -0.10
# 1                         -0.01                                     -0.14
# 2                         -0.02                                     -0.18
# 3                          0.02                                     -0.20
# 4                          0.05                                     -0.22

# %%
df_years_ice_sheets_all_mm = df_ice_sheets_all_mm.drop(df_ice_sheets_all_mm[df_ice_sheets_all_mm["Year"] % 1 > 0000].index)

# %%
df_years_ice_sheets_all_mm["Year"] = df_years_ice_sheets_all_mm["Year"].astype(int)

# %%
df_years_ice_sheets_all_mm.head(5)
# Out:
#     Year  Mass balance (mm/yr)  Mass balance uncertainty (mm/yr)  \
# 0   1992                 -0.06                             -0.35
# 12  1993                  0.29                             -0.29
# 24  1994                  0.54                             -0.29
# 36  1995                  0.40                             -0.32
# 48  1996                  0.17                             -0.33
#
#     Cumulative mass balance (mm)  Cumulative mass balance uncertainty (mm)
# 0                          -0.01                                     -0.10
# 12                          0.18                                     -0.32
# 24                          0.49                                     -0.43
# 36                          1.02                                     -0.52
# 48                          1.35                                     -0.61

# %%
df_years_ice_sheets_all_gt_mm = pd.merge(df_years_ice_sheets_all, df_years_ice_sheets_all_mm, how="left", on="Year")

# %%
df_years_ice_sheets_all_gt_mm.head(5)
# Out:
#    Year  Mass balance (Gt/yr)  Mass balance uncertainty (Gt/yr)  \
# 0  1992               22.5333                          127.4965
# 1  1993             -104.5494                          103.9689
# 2  1994             -195.5413                          102.8685
# 3  1995             -142.9034                          116.2499
# 4  1996              -59.9941                          117.2250
#
#    Cumulative mass balance (Gt)  Cumulative mass balance uncertainty (Gt)  \
# 0                        1.8778                                   36.8051
# 1                      -63.0330                                  116.0348
# 2                     -175.1651                                  155.7391
# 3                     -366.3200                                  187.2990
# 4                     -486.7987                                  220.4490
#
#    Mass balance (mm/yr)  Mass balance uncertainty (mm/yr)  \
# 0                 -0.06                             -0.35
# ...

# %%
df_years_ice_sheets_all_gt_mm.describe()
# Out:
#               Year  Mass balance (Gt/yr)  Mass balance uncertainty (Gt/yr)  \
# count    29.000000             29.000000                         29.000000
# mean   2006.000000           -259.088838                        127.402221
# std       8.514693            175.782552                         13.683793
# min    1992.000000           -669.576900                        102.868500
# 25%    1999.000000           -353.244900                        118.053400
# 50%    2006.000000           -245.213700                        125.202700
# 75%    2013.000000           -108.317400                        133.425100
# max    2020.000000             22.533300                        165.484600
#
#        Cumulative mass balance (Gt)  Cumulative mass balance uncertainty (Gt)  \
# count                     29.000000                                 29.000000
# mean                   -2609.613948                                420.035238
# ...

# %%
df_years_ice_sheets_all_gt_mm.to_csv("../data/ice sheets/years ice sheets gt + mm.csv")

# %% [markdown]
# # Sea Level

# %%
df_sea_level = pd.read_csv("../data/sea level/Change_in_Mean_Sea_Levels.csv")

# %%
df_sea_level.head(5)
# Out:
#    ObjectId Country  ISO2 ISO3  \
# 0         1   World   NaN  WLD
# 1         2   World   NaN  WLD
# 2         3   World   NaN  WLD
# 3         4   World   NaN  WLD
# 4         5   World   NaN  WLD
#
#                                            Indicator         Unit  \
# 0  Change in mean sea level: Sea level: TOPEX.Pos...  Millimeters
# 1  Change in mean sea level: Sea level: TOPEX.Pos...  Millimeters
# 2  Change in mean sea level: Sea level: TOPEX.Pos...  Millimeters
# 3  Change in mean sea level: Sea level: TOPEX.Pos...  Millimeters
# 4  Change in mean sea level: Sea level: TOPEX.Pos...  Millimeters
#
#                                               Source CTS_Code  \
# 0  National Oceanic and Atmospheric Administratio...     ECCL
# 1  National Oceanic and Atmospheric Administratio...     ECCL
# 2  National Oceanic and Atmospheric Administratio...     ECCL
# 3  National Oceanic and Atmospheric Administratio...     ECCL
# ...

# %%
df_sea_level_sub = df_sea_level.drop(columns=["Indicator", "Source", "CTS_Code", "CTS_Name", "CTS_Full_Descriptor"])

# %%
df_sea_level_sub.head(5)
# Out:
#    ObjectId Country  ISO2 ISO3         Unit         Measure         Date  \
# 0         1   World   NaN  WLD  Millimeters     Andaman Sea  D12/17/1992
# 1         2   World   NaN  WLD  Millimeters     Arabian Sea  D12/17/1992
# 2         3   World   NaN  WLD  Millimeters  Atlantic Ocean  D12/17/1992
# 3         4   World   NaN  WLD  Millimeters      Baltic Sea  D12/17/1992
# 4         5   World   NaN  WLD  Millimeters      Bay Bengal  D12/17/1992
#
#     Value
# 0  -10.34
# 1  -18.46
# 2  -15.41
# 3  196.85
# 4    3.27

# %%
df_sea_level_sub["Year"] = df_sea_level_sub["Date"].str[-4:].astype(int)
df_sea_level_sub["Month"] = df_sea_level_sub["Date"].str[1:3].astype(int)
df_sea_level_sub["Day"] = df_sea_level_sub["Date"].str[-7:-5].astype(int)

# %%
df_sea_level_sub.head(5)
# Out:
#    ObjectId Country  ISO2 ISO3         Unit         Measure         Date  \
# 0         1   World   NaN  WLD  Millimeters     Andaman Sea  D12/17/1992
# 1         2   World   NaN  WLD  Millimeters     Arabian Sea  D12/17/1992
# 2         3   World   NaN  WLD  Millimeters  Atlantic Ocean  D12/17/1992
# 3         4   World   NaN  WLD  Millimeters      Baltic Sea  D12/17/1992
# 4         5   World   NaN  WLD  Millimeters      Bay Bengal  D12/17/1992
#
#     Value  Year  Month  Day
# 0  -10.34  1992     12   17
# 1  -18.46  1992     12   17
# 2  -15.41  1992     12   17
# 3  196.85  1992     12   17
# 4    3.27  1992     12   17

# %%
df_sea_level_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35604 entries, 0 to 35603
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ObjectId  35604 non-null  int64
#  1   Country   35604 non-null  object
#  2   ISO2      0 non-null      float64
#  3   ISO3      35604 non-null  object
#  4   Unit      35604 non-null  object
#  5   Measure   35604 non-null  object
#  6   Date      35604 non-null  object
#  7   Value     35604 non-null  float64
#  8   Year      35604 non-null  int64
#  9   Month     35604 non-null  int64
#  10  Day       35604 non-null  int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 3.0+ MB

# %%
df_sea_level_sub.describe()
# Out:
#            ObjectId  ISO2         Value          Year         Month  \
# count  35604.000000   0.0  35604.000000  35604.000000  35604.000000
# mean   17802.500000   NaN     25.983479   2007.914139      6.508398
# std    10278.133829   NaN     62.781917      7.779484      3.442607
# min        1.000000   NaN   -401.850000   1992.000000      1.000000
# 25%     8901.750000   NaN     -8.552500   2002.000000      4.000000
# 50%    17802.500000   NaN     23.095000   2009.000000      7.000000
# 75%    26703.250000   NaN     58.480000   2014.000000      9.000000
# max    35604.000000   NaN    504.950000   2022.000000     12.000000
#
#                 Day
# count  35604.000000
# mean      15.688237
# std        8.815921
# min        1.000000
# 25%        8.000000
# 50%       16.000000
# 75%       23.000000
# max       31.000000

# %%
df_sea_level_sub.head(5)
# Out:
#    ObjectId Country  ISO2 ISO3         Unit         Measure         Date  \
# 0         1   World   NaN  WLD  Millimeters     Andaman Sea  D12/17/1992
# 1         2   World   NaN  WLD  Millimeters     Arabian Sea  D12/17/1992
# 2         3   World   NaN  WLD  Millimeters  Atlantic Ocean  D12/17/1992
# 3         4   World   NaN  WLD  Millimeters      Baltic Sea  D12/17/1992
# 4         5   World   NaN  WLD  Millimeters      Bay Bengal  D12/17/1992
#
#     Value  Year  Month  Day
# 0  -10.34  1992     12   17
# 1  -18.46  1992     12   17
# 2  -15.41  1992     12   17
# 3  196.85  1992     12   17
# 4    3.27  1992     12   17

# %%
df_sea_level_sub_world = df_sea_level_sub[df_sea_level_sub["Measure"] == "World"]

# %%
df_sea_level_sub_world.head(10)
# Out:
#      ObjectId Country  ISO2 ISO3         Unit Measure         Date  Value  \
# 20         21   World   NaN  WLD  Millimeters   World  D12/17/1992 -15.95
# 47         48   World   NaN  WLD  Millimeters   World  D12/27/1992 -17.65
# 71         72   World   NaN  WLD  Millimeters   World  D01/05/1993 -14.55
# 93         94   World   NaN  WLD  Millimeters   World  D01/15/1993 -19.55
# 122       123   World   NaN  WLD  Millimeters   World  D01/25/1993 -24.95
# 147       148   World   NaN  WLD  Millimeters   World  D02/05/1993 -29.05
# 172       173   World   NaN  WLD  Millimeters   World  D02/14/1993 -27.35
# 195       196   World   NaN  WLD  Millimeters   World  D02/24/1993 -21.55
# 222       223   World   NaN  WLD  Millimeters   World  D03/06/1993 -18.65
# 247       248   World   NaN  WLD  Millimeters   World  D03/16/1993 -19.15
#
#      Year  Month  Day
# 20   1992     12   17
# 47   1992     12   27
# 71   1993      1    5
# 93   1993      1   15
# 122  1993      1   25
# ...

# %%
df_sea_level_sub_world["Date"] = df_sea_level_sub_world["Date"].str[1:]
# Out:
# /var/folders/hz/rxptc1gs1zd1j75bf16_jgvr0000gn/T/ipykernel_33049/1045101945.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sea_level_sub_world["Date"] = df_sea_level_sub_world["Date"].str[1:]

# %%
df_sea_level_sub_world.head()
# Out:
#      ObjectId Country  ISO2 ISO3         Unit Measure        Date  Value  \
# 20         21   World   NaN  WLD  Millimeters   World  12/17/1992 -15.95
# 47         48   World   NaN  WLD  Millimeters   World  12/27/1992 -17.65
# 71         72   World   NaN  WLD  Millimeters   World  01/05/1993 -14.55
# 93         94   World   NaN  WLD  Millimeters   World  01/15/1993 -19.55
# 122       123   World   NaN  WLD  Millimeters   World  01/25/1993 -24.95
#
#      Year  Month  Day
# 20   1992     12   17
# 47   1992     12   27
# 71   1993      1    5
# 93   1993      1   15
# 122  1993      1   25

# %%
df_sea_level_sub_world.to_csv("../data/sea level/sea_level_world_filtered.csv")
